# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
class SimpleLinearRegression:
    # Class definition omitted -- see Moodle for code

# %% [markdown]
# # Example applications of regression

# %% [markdown]
# ## Regression of Attendance vs Gross Revenue [entire dataframe]

# %%
df = pd.read_csv("../ch07/broadway.csv")
fitter = SimpleLinearRegression(df, "Attendance", "Gross")
fitter.calc_fit()
print("Slope: {}   Intercept: {}".format(fitter.slope, fitter.intercept))
fitter.plot()
# Out:
# Slope: 94.02750409318983   Intercept: -157140.67106568743

# %% [markdown]
# ## Separate regressions for musicals and plays

# %%
df_musicals = df.query("Type == 'Musical'")
fitter = SimpleLinearRegression(df_musicals, "Attendance", "Gross")
fitter.calc_fit()
print("Slope: {}   Intercept: {}".format(fitter.slope, fitter.intercept))
fitter.plot()
# Out:
# Slope: 94.23391965802662   Intercept: -160123.95363467967

# %%
df_plays = df.query("Type == 'Play'")
fitter = SimpleLinearRegression(df_plays, "Attendance", "Gross")
fitter.calc_fit()
print("Slope: {}   Intercept: {}".format(fitter.slope, fitter.intercept))
fitter.plot()
# Out:
# Slope: 97.54401850866853   Intercept: -173911.09052704065

# %%
df_specials = df.query("Type == 'Special'")
fitter = SimpleLinearRegression(df_specials, "Attendance", "Gross")
fitter.calc_fit()
print("Slope: {}   Intercept: {}".format(fitter.slope, fitter.intercept))
fitter.plot()
# Out:
# Slope: 87.64906310624892   Intercept: -82275.44904633646

# %% [markdown]
# ## Separate regressions for musicals and plays

# %%
df_musicals = df.query("Type == 'Musical'")
fit_musicals = SimpleLinearRegression(df_musicals, "Attendance", "Gross")
fit_musicals.calc_fit()
print("Slope: {}   Intercept: {}".format(fit_musicals.slope, fit_musicals.intercept))
fit_musicals.plot()

# %%
df_plays = df.query("Type == 'Play'")
fit_plays = SimpleLinearRegression(df_plays, "Attendance", "Gross")
fit_plays.calc_fit()
print("Slope: {}   Intercept: {}".format(fit_plays.slope, fit_plays.intercept))
fit_plays.plot()

# %% [markdown]
# ## Regressions for each year of data

# %%
years = df['Year'].unique()
slopes = []
for year in years:
    df_year = df.query("Year == {}".format(year))
    fit_year = SimpleLinearRegression(df_year, "Attendance", "Gross")
    fit_year.calc_fit()
    slopes.append(fit_year.slope)
    print("{}  --  Slope: {}   Intercept: {}".format(year, fit_year.slope, fit_year.intercept))
    fit_year.plot()
    
plt.plot(years, slopes)
plt.xlabel("Year")
plt.ylabel("Slope of Attendance vs Gross")
plt.title("Attendance vs Gross over time")
plt.show()
# Out:
# /share/apps/jhub/lib64/python3.6/site-packages/pandas/core/nanops.py:805: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return np.cov(a, b)[0, 1]
# /share/apps/jhub/lib64/python3.6/site-packages/numpy/lib/function_base.py:2326: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
# 1990  --  Slope: nan   Intercept: nan
# 1991  --  Slope: 55.39637580091912   Intercept: -7580.903023954947
# 1992  --  Slope: 61.7607847495983   Intercept: -145953.6194591585
# 1993  --  Slope: 57.435682369027596   Intercept: -141996.30267137167
# 1994  --  Slope: 61.345669148008426   Intercept: -151691.86961199896
# 1995  --  Slope: 64.3087511070693   Intercept: -141702.54234164348
# 1996  --  Slope: 59.83980127594765   Intercept: -99645.43164977845
# 1997  --  Slope: 59.32913454702669   Intercept: -89738.53699057875
# 1998  --  Slope: 61.61744430080177   Intercept: -96943.56502930372
# 1999  --  Slope: 60.81077877171861   Intercept: -76015.30749594106
# 2000  --  Slope: 65.53935557866427   Intercept: -81830.69357851642
# 2001  --  Slope: 73.28366075822908   Intercept: -130194.55852318532
# 2002  --  Slope: 81.81614142617677   Intercept: -150072.1485453642
# 2003  --  Slope: 81.89813831345464   Intercept: -125594.36195789982
# 2004  --  Slope: 82.04614878224326   Intercept: -124292.12468212261
# 2005  --  Slope: 84.10656332195839   Intercept: -120078.44484335615
# 2006  --  Slope: 95.46817506983642   Intercept: -158875.3317858791
# 2007  --  Slope: 97.6293279712556   Intercept: -168697.6603758271
# 2008  --  Slope: 99.47572794711387   Intercept: -177263.93160627654
# 2009  --  Slope: 109.5696464965324   Intercept: -215634.15655970934
# 2010  --  Slope: 117.05367624266516   Intercept: -245278.56245712645
# 2011  --  Slope: 119.24196893831365   Intercept: -246565.39250446565
# 2012  --  Slope: 136.42712381508343   Intercept: -322329.0068407613
# 2013  --  Slope: 136.85538655548814   Intercept: -281341.9664982237
# 2014  --  Slope: 134.12067622498643   Intercept: -245315.40207354096
# 2015  --  Slope: 135.27138618881477   Intercept: -251882.65589426074
# 2016  --  Slope: 147.0273214328708   Intercept: -371815.47501577926
